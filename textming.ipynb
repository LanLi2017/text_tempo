# %%
import pandas as pd
import json
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
df=pd.read_csv("nasa_keyword.csv")

# %%
df
# Out:
#         Unnamed: 0                        id  \
# 0                1  55942a57c63a7fe59b495a78
# 1                2  55942a57c63a7fe59b495a78
# 2                3  55942a57c63a7fe59b495a78
# 3                4  55942a58c63a7fe59b495a79
# 4                5  55942a58c63a7fe59b495a79
# 5                6  55942a58c63a7fe59b495a79
# 6                7  55942a58c63a7fe59b495a7b
# 7                8  55942a58c63a7fe59b495a7b
# 8                9  55942a58c63a7fe59b495a7b
# 9               10  55942a58c63a7fe59b495a7b
# 10              11  55942a58c63a7fe59b495a7b
# 11              12  55942a58c63a7fe59b495a7b
# 12              13  55942a58c63a7fe59b495a7b
# 13              14  55942a58c63a7fe59b495a7b
# 14              15  55942a58c63a7fe59b495a7b
# 15              16  55942a58c63a7fe59b495a7b
# 16              17  55942a58c63a7fe59b495a7b
# 17              18  55942a58c63a7fe59b495a7b
# 18              19  55942a58c63a7fe59b495a7b
# 19              20  55942a58c63a7fe59b495a7b
# ...

# %%
with open('data.json') as json_data:
    data=json.load(json_data)

# %%
data
# Out:
# {'@context': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld',
#  '@type': 'dcat:Catalog',
#  'conformsTo': 'https://project-open-data.cio.gov/v1.1/schema',
#  'dataset': [{'@type': 'dcat:Dataset',
#    '_id': {'$oid': '55942a57c63a7fe59b495a78'},
#    'accessLevel': 'public',
#    'accrualPeriodicity': 'irregular',
#    'bureauCode': ['026:00'],
#    'contactPoint': {'fn': 'PLEASE CONTACT ORNL DAAC User Services',
#     'hasEmail': 'mailto:ornldaac@ornl.gov'},
#    'description': 'USGS 15 minute stream flow data for Kings Creek on the Konza Prairie',
#    'distribution': [{'accessURL': 'http://daac.ornl.gov/FIFE/guides/15_min_strm_flow.html',
#      'mediaType': 'application/octet-stream'}],
#    'identifier': 'C179003030-ORNL_DAAC__1',
#    'issued': '2008-12-02T00:00:00.000Z',
#    'keyword': ['EARTH SCIENCE', 'HYDROSPHERE', 'SURFACE WATER'],
#    'landingPage': 'http://reverb.echo.nasa.gov/reverb?selected=C179003030-ORNL_DAAC',
#    'language': ['en-US'],
# ...

# %%
title=[]
for result in data['dataset']:
    title.append(result['title'])
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file',)).History will not be written to the database.

# %%
title_tokens=[word_tokenize(i) for i in title]
for i in title_tokens:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-40-0d5514eec275> in <module>()
# ----> 1 title_tokens=[word_tokenize(i) for i in title]
#       2 for i in title_tokens:
#       3     print(i)
#
# <ipython-input-40-0d5514eec275> in <listcomp>(.0)
# ----> 1 title_tokens=[word_tokenize(i) for i in title]
#       2 for i in title_tokens:
#       3     print(i)
#
# ~/anaconda/lib/python3.6/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     128     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     129     return [token for sent in sentences
# --> 130             for token in _treebank_word_tokenizer.tokenize(sent)]
#
# ~/anaconda/lib/python3.6/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ...

# %%
word_title={x:title.count(x) for x in title}

# %%
word_title
# Out:
# {'15 Minute Stream Flow Data: USGS (FIFE)': 3,
#  '2000 Pilot Environmental Sustainability Index (ESI)': 3,
#  '2001 Environmental Sustainability Index (ESI)': 4,
#  '2002 Environmental Sustainability Index (ESI)': 4,
#  '2005 Environmental Sustainability Index (ESI)': 5,
#  '2008 Environmental Performance Index (EPI)': 4,
#  '2008 Natural Resource Management Index (NRMI)': 3,
#  '2010 Environmental Performance Index (EPI)': 3,
#  '2012 Environmental Performance Index and Pilot Trend Environmental Performance Index': 4,
#  '30 Minute Rainfall Data (FIFE)': 3,
#  'A Global Database of Carbon and Nutrient Concentrations of Green and Senesced Leaves': 3,
#  'A Global Database of Gas Fluxes from Soils after Rewetting or Thawing, Version 1.0': 3,
#  'A Global Database of Soil Respiration Data, Version 1.0': 3,
#  'A Global Database of Soil Respiration Data, Version 2.0': 3,
#  'ACES CONTINUOUS DATA V1': 4,
#  'ACES ELECTRIC FIELD MILL V1': 4,
#  'ACES LOG DATA V1': 4,
# ...

# %%
word_tokens=tokenize(word_title)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-5089725171b6> in <module>()
# ----> 1 word_tokens=tokenize(word_title)
#
# ~/anaconda/lib/python3.6/tokenize.py in tokenize(readline)
#     484     # built yet and tokenize is imported.
#     485     from itertools import chain, repeat
# --> 486     encoding, consumed = detect_encoding(readline)
#     487     rl_gen = iter(readline, b"")
#     488     empty = repeat(b"")
#
# ~/anaconda/lib/python3.6/tokenize.py in detect_encoding(readline)
#     421         return encoding
#     422
# --> 423     first = read_or_stop()
#     424     if first.startswith(BOM_UTF8):
#     425         bom_found = True
#
# ~/anaconda/lib/python3.6/tokenize.py in read_or_stop()
#     379     def read_or_stop():
#     380         try:
# --> 381             return readline()
#     382         except StopIteration:
# ...
